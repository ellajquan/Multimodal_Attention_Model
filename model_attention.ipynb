# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, GlobalAveragePooling2D, concatenate, BatchNormalization, Conv2D, Activation, Add, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef, confusion_matrix
import boto3
from io import BytesIO
import json
import random

# %%
# 2. Load Config
# Load configuration from config.json
with open('config.json', 'r') as config_file:
    config = json.load(config_file)

# Set seed
tf.random.set_seed(config["seed"])

# Load configuration values
bucket_name = config["s3_bucket_name"]
train_labels_path = config["train_labels_path"]
test_labels_path = config["test_labels_path"]
train_prefix = config["output_dir_train"]
test_prefix = config["output_dir_test"]
as_gray = config["as_gray"]
img_rows, img_cols = config["img_rows"], config["img_cols"]
channels = config["in_channel"]
num_classes = config["num_classes"]
batch_size = config["batch_size"]
all_epochs = config["all_epochs"]
input_shape = tuple(config["input_shape"])

# Define input shape
input_img = Input(shape=input_shape)

# Initialize S3 client
s3 = boto3.client('s3')

# Helper function to upload numpy arrays to S3
def upload_to_s3(np_array, bucket, key):
    with BytesIO() as buffer:
        np.save(buffer, np_array)
        buffer.seek(0)
        s3.put_object(Bucket=bucket, Key=key, Body=buffer.getvalue())

# Helper function to load numpy arrays from S3
def load_from_s3(bucket, key):
    obj = s3.get_object(Bucket=bucket, Key=key)
    return np.load(BytesIO(obj['Body'].read()))

# %%
# Load train labels from S3
obj = s3.get_object(Bucket=bucket_name, Key=train_labels_path)
train_df = pd.read_excel(BytesIO(obj['Body'].read()))

# Split the data into training and validation sets
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=1203)

# Data Loading and Preprocessing with Improved Augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)

def load_images_from_s3(patient_ids, img_rows, img_cols, bucket_name):
    images = []
    for img_path in patient_ids:
        key = img_path.strip()
        print(f"Attempting to load key: {key}")
        try:
            obj = s3.get_object(Bucket=bucket_name, Key=key)
            img = tf.image.decode_png(obj['Body'].read(), channels=3)
            img = tf.image.resize(img, [img_rows, img_cols])
            images.append(img)
        except s3.exceptions.NoSuchKey as e:
            print(f"Error: Key {key} does not exist.")
    if images:
        return tf.stack(images)
    else:
        raise ValueError("No valid images were loaded.")

# %%
# Load CC and MLO views for both left and right breasts for training and validation
x_train_CC = load_images_from_s3(train_df.L_CC_file.values.tolist() + train_df.R_CC_file.values.tolist(), img_rows, img_cols, bucket_name)
x_train_MLO = load_images_from_s3(train_df.L_MLO_file.values.tolist() + train_df.R_MLO_file.values.tolist(), img_rows, img_cols, bucket_name)

x_val_CC = load_images_from_s3(val_df.L_CC_file.values.tolist() + val_df.R_CC_file.values.tolist(), img_rows, img_cols, bucket_name)
x_val_MLO = load_images_from_s3(val_df.L_MLO_file.values.tolist() + val_df.R_MLO_file.values.tolist(), img_rows, img_cols, bucket_name)

# Generate y_train and y_val with the correct number of samples
y_train = tf.keras.utils.to_categorical(train_df.target.values.tolist() * 2, num_classes=2)[:len(x_train_CC)]
y_val = tf.keras.utils.to_categorical(val_df.target.values.tolist() * 2, num_classes=2)[:len(x_val_CC)]

# Print shapes of x and y to verify dimensions
print(f"x_train_CC shape: {x_train_CC.shape}")
print(f"x_train_MLO shape: {x_train_MLO.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_val_CC shape: {x_val_CC.shape}")
print(f"x_val_MLO shape: {x_val_MLO.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Attempting to load key: CMMD-D2/train/PNGs/D2-0407_L_CC.png
# W0000 00:00:1730347706.228584    4296 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Attempting to load key: CMMD-D2/train/PNGs/D2-0574_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0610_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0098_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0671_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0364_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0230_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0406_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0014_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0125_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0556_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0059_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0453_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0130_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0269_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0346_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0558_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0048_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0078_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0509_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0080_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0439_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0725_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0286_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0633_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0351_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0533_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0504_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0258_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0589_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0314_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0010_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0450_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0055_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0476_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0089_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0738_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0179_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0416_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0550_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0323_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0167_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0074_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0136_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0209_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0246_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0575_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0149_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0191_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0409_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0686_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0634_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0532_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0408_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0679_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0107_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0298_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0391_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0119_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0043_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0414_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0295_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0069_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0359_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0021_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0325_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0203_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0303_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0422_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0458_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0290_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0609_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0301_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0401_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0051_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0600_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0186_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0512_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0168_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0264_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0353_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0333_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0675_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0543_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0204_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0099_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0622_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0318_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0009_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0506_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0053_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0428_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0229_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0194_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0079_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0219_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0394_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0628_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0316_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0563_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0283_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0722_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0013_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0011_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0481_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0618_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0399_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0178_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0522_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0688_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0379_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0109_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0535_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0425_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0211_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0743_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0501_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0252_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0291_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0653_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0588_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0122_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0114_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0516_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0454_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0647_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0393_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0275_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0606_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0536_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0404_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0113_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0489_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0062_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0083_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0525_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0433_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0067_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0735_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0225_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0643_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0315_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0060_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0372_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0567_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0045_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0038_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0387_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0617_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0577_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0341_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0277_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0472_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0075_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0378_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0382_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0138_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0626_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0436_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0118_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0356_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0602_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0299_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0085_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0261_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0278_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0305_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0698_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0449_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0573_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0271_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0338_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0365_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0170_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0056_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0446_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0597_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0569_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0724_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0128_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0131_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0616_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0255_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0552_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0311_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0697_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0139_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0519_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0411_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0498_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0082_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0332_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0245_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0174_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0708_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0071_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0727_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0292_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0171_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0496_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0329_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0148_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0689_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0534_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0461_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0091_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0383_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0247_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0268_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0529_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0418_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0480_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0105_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0028_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0395_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0747_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0154_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0324_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0676_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0692_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0508_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0322_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0227_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0145_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0730_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0656_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0126_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0180_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0187_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0198_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0161_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0650_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0135_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0443_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0486_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0593_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0342_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0668_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0300_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0256_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0306_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0549_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0320_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0539_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0417_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0308_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0749_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0369_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0377_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0713_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0513_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0500_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0368_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0415_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0695_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0231_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0313_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0630_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0307_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0583_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0537_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0200_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0580_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0039_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0210_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0027_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0474_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0221_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0152_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0490_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0627_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0442_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0274_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0279_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0551_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0115_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0487_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0151_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0541_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0517_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0477_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0710_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0629_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0350_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0142_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0658_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0280_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0360_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0582_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0153_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0586_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0462_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0451_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0682_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0421_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0623_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0132_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0205_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0687_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0273_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0347_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0037_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0249_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0022_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0530_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0123_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0046_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0562_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0503_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0302_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0584_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0224_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0619_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0001_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0208_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0424_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0482_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0197_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0604_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0728_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0088_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0635_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0163_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0396_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0084_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0721_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0095_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0741_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0632_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0326_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0731_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0527_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0025_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0030_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0702_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0748_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0076_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0554_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0717_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0485_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0005_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0488_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0663_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0455_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0674_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0175_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0478_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0571_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0557_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0740_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0636_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0086_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0392_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0015_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0016_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0156_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0195_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0371_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0598_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0321_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0216_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0376_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0206_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0177_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0555_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0493_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0348_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0017_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0063_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0542_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0386_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0463_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0709_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0739_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0479_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0510_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0744_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0570_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0429_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0336_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0591_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0257_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0160_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0746_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0546_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0217_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0052_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0294_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0087_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0100_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0042_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0068_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0590_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0133_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0637_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0603_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0244_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0304_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0004_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0366_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0263_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0420_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0670_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0614_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0103_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0328_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0223_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0190_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0234_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0729_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0659_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0072_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0035_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0024_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0581_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0471_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0665_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0214_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0248_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0023_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0335_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0093_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0066_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0212_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0374_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0585_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0173_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0703_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0465_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0237_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0215_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0081_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0232_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0390_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0222_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0140_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0282_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0018_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0492_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0666_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0693_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0460_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0141_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0560_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0625_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0218_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0050_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0327_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0233_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0526_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0172_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0343_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0159_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0595_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0331_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0182_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0250_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0712_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0334_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0192_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0499_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0287_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0538_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0355_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0715_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0188_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0147_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0561_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0521_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0201_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0236_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0340_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0196_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0077_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0397_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0683_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0599_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0272_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0662_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0507_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0181_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0157_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0716_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0700_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0694_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0726_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0251_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0646_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0317_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0226_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0612_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0124_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0427_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0704_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0640_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0166_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0733_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0002_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0134_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0544_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0639_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0681_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0296_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0049_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0524_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0553_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0438_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0242_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0339_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0620_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0297_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0344_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0494_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0664_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0578_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0475_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0389_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0605_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0267_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0309_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0345_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0469_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0615_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0531_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0457_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0112_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0054_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0164_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0370_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0144_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0281_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0672_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0678_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0207_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0129_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0352_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0101_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0202_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0673_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0034_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0502_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0110_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0714_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0213_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0020_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0381_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0572_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0104_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0097_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0358_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0621_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0284_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0012_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0319_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0006_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0649_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0312_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0183_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0169_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0611_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0528_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0260_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0711_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0684_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0155_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0594_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0036_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0680_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0495_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0437_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0434_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0660_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0065_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0631_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0243_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0685_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0403_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0150_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0587_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0238_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0041_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0064_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0447_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0444_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0440_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0413_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0736_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0047_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0032_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0120_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0448_L_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0407_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0574_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0610_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0098_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0671_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0364_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0230_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0406_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0014_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0125_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0556_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0059_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0453_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0130_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0269_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0346_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0558_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0048_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0078_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0509_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0080_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0439_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0725_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0286_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0633_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0351_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0533_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0504_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0258_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0589_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0314_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0010_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0450_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0055_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0476_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0089_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0738_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0179_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0416_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0550_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0323_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0167_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0074_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0136_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0209_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0246_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0575_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0149_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0191_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0409_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0686_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0634_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0532_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0408_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0679_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0107_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0298_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0391_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0119_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0043_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0414_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0295_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0069_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0359_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0021_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0325_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0203_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0303_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0422_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0458_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0290_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0609_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0301_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0401_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0051_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0600_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0186_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0512_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0168_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0264_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0353_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0333_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0675_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0543_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0204_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0099_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0622_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0318_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0009_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0506_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0053_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0428_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0229_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0194_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0079_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0219_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0394_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0628_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0316_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0563_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0283_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0722_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0013_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0011_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0481_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0618_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0399_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0178_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0522_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0688_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0379_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0109_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0535_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0425_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0211_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0743_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0501_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0252_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0291_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0653_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0588_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0122_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0114_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0516_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0454_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0647_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0393_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0275_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0606_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0536_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0404_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0113_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0489_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0062_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0083_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0525_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0433_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0067_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0735_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0225_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0643_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0315_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0060_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0372_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0567_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0045_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0038_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0387_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0617_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0577_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0341_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0277_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0472_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0075_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0378_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0382_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0138_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0626_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0436_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0118_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0356_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0602_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0299_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0085_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0261_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0278_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0305_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0698_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0449_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0573_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0271_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0338_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0365_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0170_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0056_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0446_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0597_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0569_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0724_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0128_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0131_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0616_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0255_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0552_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0311_R_CC.png
# Error: Key CMMD-D2/train/PNGs/D2-0311_R_CC.png does not exist.
# Attempting to load key: CMMD-D2/train/PNGs/D2-0697_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0139_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0519_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0411_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0498_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0082_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0332_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0245_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0174_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0708_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0071_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0727_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0292_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0171_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0496_R_CC.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0329_R_CC.png
# ...
# Attempting to load key: CMMD-D2/train/PNGs/D2-0270_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0121_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0162_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0654_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0518_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0354_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0645_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0483_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0276_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0467_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0373_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0293_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0677_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0380_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0505_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0102_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0384_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0031_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0456_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0473_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0361_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0641_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0388_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0019_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0648_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0070_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0515_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0289_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0337_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0288_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0262_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0426_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0655_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0732_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0651_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0596_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0239_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0375_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0545_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0235_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0026_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0568_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0719_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0592_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0146_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0718_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0737_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0349_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0398_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0642_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0108_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0285_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0058_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0491_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0459_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0576_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0607_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0497_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0669_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0601_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0468_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0699_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0412_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0435_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0720_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0008_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0564_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0096_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0402_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0734_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0464_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0613_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0400_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0094_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0652_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0430_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0116_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0127_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0547_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0254_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0661_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0511_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0445_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0137_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0540_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0514_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0029_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0723_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0523_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0357_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0667_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0057_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0520_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0644_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0189_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0193_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0690_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0696_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0548_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0707_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0452_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0470_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0484_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0638_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0330_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0033_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0624_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0310_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0117_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0362_L_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0432_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0385_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0176_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0185_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0441_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0007_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0431_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0266_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0363_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0410_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0143_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0466_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0657_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0566_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0579_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0003_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0419_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0040_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0745_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0111_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0241_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0199_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0423_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0705_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0405_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0106_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0165_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0044_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0228_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0608_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0742_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0184_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0691_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0253_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0240_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0073_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0061_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0559_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0270_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0121_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0162_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0654_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0518_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0354_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0645_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0483_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0276_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0467_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0373_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0293_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0677_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0380_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0505_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0102_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0384_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0031_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0456_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0473_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0361_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0641_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0388_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0019_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0648_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0070_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0515_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0289_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0337_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0288_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0262_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0426_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0655_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0732_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0651_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0596_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0239_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0375_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0545_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0235_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0026_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0568_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0719_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0592_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0146_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0718_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0737_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0349_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0398_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0642_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0108_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0285_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0058_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0491_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0459_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0576_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0607_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0497_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0669_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0601_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0468_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0699_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0412_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0435_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0720_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0008_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0564_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0096_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0402_R_MLO.png
# Error: Key CMMD-D2/train/PNGs/D2-0402_R_MLO.png does not exist.
# Attempting to load key: CMMD-D2/train/PNGs/D2-0734_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0464_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0613_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0400_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0094_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0652_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0430_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0116_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0127_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0547_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0254_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0661_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0511_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0445_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0137_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0540_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0514_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0029_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0723_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0523_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0357_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0667_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0057_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0520_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0644_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0189_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0193_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0690_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0696_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0548_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0707_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0452_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0470_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0484_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0638_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0330_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0033_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0624_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0310_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0117_R_MLO.png
# Attempting to load key: CMMD-D2/train/PNGs/D2-0362_R_MLO.png
# x_train_CC shape: (1179, 256, 256, 3)
# x_train_MLO shape: (1179, 256, 256, 3)
# y_train shape: (1179, 2)
# x_val_CC shape: (295, 256, 256, 3)
# x_val_MLO shape: (295, 256, 256, 3)
# y_val shape: (295, 2)

# %%
# Channel Spatial Attention
channel_axis = 1 if tf.keras.backend.image_data_format() == "channels_first" else 3

def channel_attention(input_xs, reduction_ratio=0.125):
    channel = int(input_xs.shape[channel_axis])
    maxpool_channel = tf.keras.layers.GlobalMaxPooling2D()(input_xs)
    maxpool_channel = tf.keras.layers.Reshape((1, 1, channel))(maxpool_channel)
    avgpool_channel = tf.keras.layers.GlobalAveragePooling2D()(input_xs)
    avgpool_channel = tf.keras.layers.Reshape((1, 1, channel))(avgpool_channel)
    Dense_One = tf.keras.layers.Dense(units=int(channel * reduction_ratio), activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    Dense_Two = tf.keras.layers.Dense(units=int(channel), activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')

    mlp_1_max = Dense_One(maxpool_channel)
    mlp_2_max = Dense_Two(mlp_1_max)
    mlp_1_avg = Dense_One(avgpool_channel)
    mlp_2_avg = Dense_Two(mlp_1_avg)
    channel_attention_feature = tf.keras.layers.Add()([mlp_2_max, mlp_2_avg])
    channel_attention_feature = tf.keras.layers.Activation('sigmoid')(channel_attention_feature)
    return tf.keras.layers.Multiply()([channel_attention_feature, input_xs])

def spatial_attention(channel_refined_feature):
    maxpool_spatial = tf.keras.layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(channel_refined_feature)
    avgpool_spatial = tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(channel_refined_feature)
    max_avg_pool_spatial = tf.keras.layers.Concatenate(axis=3)([maxpool_spatial, avgpool_spatial])
    return tf.keras.layers.Conv2D(filters=1, kernel_size=(3, 3), padding="same", activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(max_avg_pool_spatial)

def CSA(input_xs, reduction_ratio=0.5):
    channel_refined_feature = channel_attention(input_xs, reduction_ratio=reduction_ratio)
    spatial_attention_feature = spatial_attention(channel_refined_feature)
    refined_feature = tf.keras.layers.Multiply()([channel_refined_feature, spatial_attention_feature])
    return tf.keras.layers.Add()([refined_feature, input_xs])

# %%
# Improved Model Definition with Two ResNet50 Base Models for CC and MLO Views
# Input tensors for CC and MLO views
I1 = Input(shape=(img_rows, img_cols, 3))
model1 = ResNet50(weights='imagenet', include_top=False, input_tensor=I1, pooling=None)
MLO_model = Model(inputs=I1, outputs=model1.get_layer('conv4_block6_out').output)


I2 = Input(shape=(img_rows, img_cols, 3))
model2 = ResNet50(weights='imagenet', include_top=False, input_tensor=I2, pooling=None)
for layer in model2.layers:
    layer.name = layer.name + '_2'
CC_model = Model(inputs=I2, outputs=model2.get_layer('conv4_block6_out_2').output)


x_mlo = MLO_model.output
x_cc = CC_model.output

# Combine the outputs from MLO and CC views
c1 = concatenate([x_mlo, x_cc], axis=2)

# %%
# Define bottleneck block
def bottleneck_Block(input_tensor, nb_filters, strides=(1, 1), with_conv_shortcut=False):
    (nb_filter1, nb_filter2, nb_filter3) = nb_filters

    x = Conv2D(nb_filter1, (1, 1), strides=strides, kernel_initializer='he_normal')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(nb_filter2, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(nb_filter3, (1, 1), kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)

    if with_conv_shortcut:
        shortcut = Conv2D(nb_filter3, (1, 1), strides=strides, kernel_initializer='he_normal')(input_tensor)
        shortcut = BatchNormalization()(shortcut)
        x = Add()([x, shortcut])
    else:
        x = Add()([x, input_tensor])

    x = Activation('relu')(x)
    return x

# %%
Downsampling_model = Model(digit_input, out_d)
digit_input = Input(shape=(16, 16, 1024))

## intra-modality attention
a1=Self_Attention(1024)(c1)

x1 = tf.keras.layers.Lambda(tf.split, arguments={'axis': 2, 'num_or_size_splits': 2})(a1)
x11,x12=x1[0], x1[1]
h1, w1, c1 = x11.shape[1],x11.shape[2],x11.shape[3]
x11=Reshape((h1, w1, c1))(x11)
x12=Reshape((h1, w1, c1))(x12)

x11=Downsampling_model(x11)
x12=Downsampling_model(x12)

## intra-modality attention
a2=Self_Attention(1024)(x_us)

x2 = bottleneck_Block(a2, nb_filters=[512, 512, 2048], strides=(2, 2), with_conv_shortcut=True)
x2 = bottleneck_Block(x2, nb_filters=[512, 512, 2048])
x2 = bottleneck_Block(x2, nb_filters=[512, 512, 2048])
ccc = concatenate([x11, x12, x2], axis=2)

## inter-modality attention
a3=Self_Attention(2048)(ccc)

x6 = tf.keras.layers.Lambda(tf.split, arguments={'axis': 2, 'num_or_size_splits': 3})(a3)
x61, x62, x63=x6[0], x6[1] ,x6[2]
h6, w6, c6 = x61.shape[1],x61.shape[2],x61.shape[3]
x61=Reshape((h6, w6, c6))(x61)
x62=Reshape((h6, w6, c6))(x62)
x63=Reshape((h6, w6, c6))(x63)
c6 = concatenate([x61, x62, x63], axis=3)

## channel_spatial_attention
x3=CSA(c6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 Downsampling_model = Model(digit_input, out_d)
#       2 digit_input = Input(shape=(16, 16, 1024))
#       4 ## intra-modality attention
#
# NameError: name 'digit_input' is not defined

# %%
# Define the final model
output = GlobalAveragePooling2D()(c6)
output = Dense(512, activation="relu")(output)
output = Dropout(0.3)(output)
output = Dense(num_classes, activation='softmax', name='output')(output)
model = Model(inputs=[MLO_model.input, CC_model.input], outputs=output)

# %%
# Define the final model
model = Model(inputs=[MLO_model.input, CC_model.input], outputs=output)

# Compile the model with custom metrics
model.compile(
    optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate for more stable training
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.AUC(name='auc')
    ]
)
